# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import json
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import timeit

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 771

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | smithers
# Processing Record 3 of Set 1 | saldanha
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | oranjemund
# Processing Record 8 of Set 1 | alice springs
# Processing Record 9 of Set 1 | aguimes
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | baringo
# Processing Record 12 of Set 1 | portland
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | caravelas
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | la ronge
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | salmon creek
# Processing Record 20 of Set 1 | butaritari
# Processing Record 21 of Set 1 | yar-sale
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | poso
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | figeac
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | ojinaga
# Processing Record 28 of Set 1 | usolye
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | nakamura
# Processing Record 32 of Set 1 | rovaniemi
# Processing Record 33 of Set 1 | sao joao da barra
# Processing Record 34 of Set 1 | harper
# Processing Record 35 of Set 1 | la orilla
# Processing Record 36 of Set 1 | mackay
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | qaanaaq
# Processing Record 41 of Set 1 | viedma
# Processing Record 42 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | ballina
# Processing Record 45 of Set 1 | kilindoni
# Processing Record 46 of Set 1 | waipawa
# Processing Record 47 of Set 1 | biak
# Processing Record 48 of Set 1 | caibarien
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | andra
# Processing Record 1 of Set 2 | kloulklubed
# Processing Record 2 of Set 2 | bethel
# Processing Record 3 of Set 2 | derbent
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | olinda
# Processing Record 6 of Set 2 | sangar
# Processing Record 7 of Set 2 | abbeville
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | colares
# Processing Record 10 of Set 2 | kaka
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | sawakin
# Processing Record 13 of Set 2 | oblivskaya
# Processing Record 14 of Set 2 | mount gambier
# Processing Record 15 of Set 2 | yurginskoye
# Processing Record 16 of Set 2 | murupara
# Processing Record 17 of Set 2 | san andres
# Processing Record 18 of Set 2 | hasaki
# Processing Record 19 of Set 2 | bredasdorp
# Processing Record 20 of Set 2 | sabancuy
# Processing Record 21 of Set 2 | roald
# Processing Record 22 of Set 2 | saint-joseph
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 2 | phan thiet
# Processing Record 27 of Set 2 | mikuni
# Processing Record 28 of Set 2 | puerto ayora
# Processing Record 29 of Set 2 | matale
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 2 | pandan
# Processing Record 35 of Set 2 | lazaro cardenas
# Processing Record 36 of Set 2 | tura
# Processing Record 37 of Set 2 | moerai
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | cabo san lucas
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | port hardy
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | paamiut
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | roshchino
# Processing Record 47 of Set 2 | tecalitlan
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | punta arenas
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | saint-augustin
# Processing Record 2 of Set 3 | sorong
# Processing Record 3 of Set 3 | dingle
# Processing Record 4 of Set 3 | anshun
# Processing Record 5 of Set 3 | honningsvag
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | puerto el triunfo
# Processing Record 8 of Set 3 | vila velha
# Processing Record 9 of Set 3 | clyde river
# Processing Record 10 of Set 3 | corsicana
# Processing Record 11 of Set 3 | ottersberg
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | klaksvik
# Processing Record 14 of Set 3 | padang
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | vaini
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | kirkenaer
# Processing Record 19 of Set 3 | melilla
# Processing Record 20 of Set 3 | sioux lookout
# Processing Record 21 of Set 3 | vestmannaeyjar
# Processing Record 22 of Set 3 | abalak
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | saint anthony
# Processing Record 26 of Set 3 | uray
# Processing Record 27 of Set 3 | kavieng
# Processing Record 28 of Set 3 | mahon
# Processing Record 29 of Set 3 | brookings
# Processing Record 30 of Set 3 | hit
# Processing Record 31 of Set 3 | ponta do sol
# Processing Record 32 of Set 3 | ilulissat
# Processing Record 33 of Set 3 | tambopata
# Processing Record 34 of Set 3 | nuevo progreso
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | gornopravdinsk
# Processing Record 37 of Set 3 | east london
# Processing Record 38 of Set 3 | chicama
# Processing Record 39 of Set 3 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 3 | leningradskiy
# Processing Record 41 of Set 3 | kodiak
# Processing Record 42 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 3 | port alfred
# Processing Record 44 of Set 3 | srivardhan
# Processing Record 45 of Set 3 | faanui
# Processing Record 46 of Set 3 | karkaralinsk
# City not found. Skipping...
# Processing Record 47 of Set 3 | woodbridge
# Processing Record 48 of Set 3 | timmins
# Processing Record 49 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | olafsvik
# Processing Record 2 of Set 4 | kotido
# Processing Record 3 of Set 4 | grindavik
# Processing Record 4 of Set 4 | kabale
# Processing Record 5 of Set 4 | coahuayana
# Processing Record 6 of Set 4 | hithadhoo
# Processing Record 7 of Set 4 | chiredzi
# Processing Record 8 of Set 4 | zihuatanejo
# Processing Record 9 of Set 4 | kamaishi
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 12 of Set 4 | yellowknife
# Processing Record 13 of Set 4 | kruisfontein
# Processing Record 14 of Set 4 | wynyard
# Processing Record 15 of Set 4 | nemuro
# Processing Record 16 of Set 4 | cervo
# Processing Record 17 of Set 4 | oktyabrskiy
# Processing Record 18 of Set 4 | dikson
# Processing Record 19 of Set 4 | coos bay
# Processing Record 20 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 21 of Set 4 | am timan
# Processing Record 22 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | burnie
# Processing Record 25 of Set 4 | mahebourg
# Processing Record 26 of Set 4 | alofi
# Processing Record 27 of Set 4 | chota
# Processing Record 28 of Set 4 | hilo
# Processing Record 29 of Set 4 | langsa
# Processing Record 30 of Set 4 | iqaluit
# Processing Record 31 of Set 4 | sao filipe
# Processing Record 32 of Set 4 | zaysan
# Processing Record 33 of Set 4 | khatanga
# Processing Record 34 of Set 4 | baghdad
# Processing Record 35 of Set 4 | zyukayka
# Processing Record 36 of Set 4 | kathmandu
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | cooma
# Processing Record 40 of Set 4 | port-gentil
# Processing Record 41 of Set 4 | petropavl
# Processing Record 42 of Set 4 | ishigaki
# Processing Record 43 of Set 4 | rio gallegos
# Processing Record 44 of Set 4 | vostok
# Processing Record 45 of Set 4 | ilhabela
# Processing Record 46 of Set 4 | okha
# Processing Record 47 of Set 4 | bambous virieux
# Processing Record 48 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 4 | shingu
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | george
# Processing Record 2 of Set 5 | kenitra
# Processing Record 3 of Set 5 | westport
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | dongsheng
# Processing Record 6 of Set 5 | luang prabang
# Processing Record 7 of Set 5 | williamsburg
# Processing Record 8 of Set 5 | lorengau
# Processing Record 9 of Set 5 | rawson
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | gamboma
# Processing Record 12 of Set 5 | okhotsk
# Processing Record 13 of Set 5 | sasovo
# Processing Record 14 of Set 5 | aswan
# Processing Record 15 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 5 | pacific grove
# Processing Record 18 of Set 5 | homer
# Processing Record 19 of Set 5 | altay
# Processing Record 20 of Set 5 | les cayes
# Processing Record 21 of Set 5 | port blair
# Processing Record 22 of Set 5 | mosquera
# Processing Record 23 of Set 5 | saint-philippe
# Processing Record 24 of Set 5 | egvekinot
# Processing Record 25 of Set 5 | port-cartier
# Processing Record 26 of Set 5 | fare
# Processing Record 27 of Set 5 | lensk
# Processing Record 28 of Set 5 | roebourne
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | avarua
# Processing Record 31 of Set 5 | tessalit
# Processing Record 32 of Set 5 | vilcun
# Processing Record 33 of Set 5 | emerald
# Processing Record 34 of Set 5 | severo-kurilsk
# Processing Record 35 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | lavrentiya
# Processing Record 37 of Set 5 | mehriz
# Processing Record 38 of Set 5 | georgetown
# Processing Record 39 of Set 5 | atuona
# Processing Record 40 of Set 5 | plettenberg bay
# Processing Record 41 of Set 5 | pevek
# Processing Record 42 of Set 5 | bairiki
# Processing Record 43 of Set 5 | barra patuca
# Processing Record 44 of Set 5 | zhatay
# Processing Record 45 of Set 5 | nadym
# Processing Record 46 of Set 5 | molteno
# Processing Record 47 of Set 5 | cayenne
# Processing Record 48 of Set 5 | aras
# Processing Record 49 of Set 5 | sinnamary
# Processing Record 50 of Set 5 | usevya
# Processing Record 1 of Set 6 | garut
# Processing Record 2 of Set 6 | roma
# Processing Record 3 of Set 6 | shache
# Processing Record 4 of Set 6 | camacha
# Processing Record 5 of Set 6 | kathu
# Processing Record 6 of Set 6 | bereda
# Processing Record 7 of Set 6 | baculin
# Processing Record 8 of Set 6 | buta
# Processing Record 9 of Set 6 | le vauclin
# Processing Record 10 of Set 6 | breves
# Processing Record 11 of Set 6 | metlaltoyuca
# Processing Record 12 of Set 6 | nanortalik
# Processing Record 13 of Set 6 | carnarvon
# Processing Record 14 of Set 6 | krasnyy yar
# Processing Record 15 of Set 6 | kuntaur
# Processing Record 16 of Set 6 | bagotville
# Processing Record 17 of Set 6 | turka
# Processing Record 18 of Set 6 | havelock
# Processing Record 19 of Set 6 | camargo
# Processing Record 20 of Set 6 | sainte-maxime
# Processing Record 21 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 23 of Set 6 | emirdag
# Processing Record 24 of Set 6 | omboue
# Processing Record 25 of Set 6 | ahuimanu
# Processing Record 26 of Set 6 | kiruna
# Processing Record 27 of Set 6 | ahipara
# Processing Record 28 of Set 6 | mount isa
# Processing Record 29 of Set 6 | santa maria
# Processing Record 30 of Set 6 | ornskoldsvik
# Processing Record 31 of Set 6 | inhambane
# Processing Record 32 of Set 6 | carauari
# Processing Record 33 of Set 6 | toumodi
# Processing Record 34 of Set 6 | tiksi
# Processing Record 35 of Set 6 | ionia
# Processing Record 36 of Set 6 | micheweni
# Processing Record 37 of Set 6 | baijiantan
# Processing Record 38 of Set 6 | adrar
# Processing Record 39 of Set 6 | naze
# Processing Record 40 of Set 6 | santiago del estero
# Processing Record 41 of Set 6 | placido de castro
# Processing Record 42 of Set 6 | maarianhamina
# Processing Record 43 of Set 6 | yamada
# Processing Record 44 of Set 6 | kysyl-syr
# Processing Record 45 of Set 6 | barrow
# Processing Record 46 of Set 6 | gaziantep
# Processing Record 47 of Set 6 | natal
# Processing Record 48 of Set 6 | trairi
# Processing Record 49 of Set 6 | sao jose da coroa grande
# Processing Record 50 of Set 6 | hovd
# Processing Record 1 of Set 7 | alenquer
# Processing Record 2 of Set 7 | karratha
# Processing Record 3 of Set 7 | pauini
# Processing Record 4 of Set 7 | ostrovnoy
# Processing Record 5 of Set 7 | teya
# Processing Record 6 of Set 7 | tabou
# Processing Record 7 of Set 7 | pringsewu
# Processing Record 8 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 9 of Set 7 | houma
# Processing Record 10 of Set 7 | codrington
# Processing Record 11 of Set 7 | novosheshminsk
# Processing Record 12 of Set 7 | fonte boa
# Processing Record 13 of Set 7 | half moon bay
# Processing Record 14 of Set 7 | brinkovskaya
# Processing Record 15 of Set 7 | oussouye
# Processing Record 16 of Set 7 | capaci
# Processing Record 17 of Set 7 | nuuk
# Processing Record 18 of Set 7 | narathiwat
# Processing Record 19 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 7 | kendari
# Processing Record 21 of Set 7 | paita
# Processing Record 22 of Set 7 | lubsko
# Processing Record 23 of Set 7 | luderitz
# Processing Record 24 of Set 7 | meulaboh
# Processing Record 25 of Set 7 | asau
# Processing Record 26 of Set 7 | tanete
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | iquitos
# Processing Record 29 of Set 7 | tasiilaq
# Processing Record 30 of Set 7 | asha
# Processing Record 31 of Set 7 | miandrivazo
# Processing Record 32 of Set 7 | igrim
# Processing Record 33 of Set 7 | ekhabi
# Processing Record 34 of Set 7 | flin flon
# Processing Record 35 of Set 7 | matay
# Processing Record 36 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 37 of Set 7 | cascavel
# Processing Record 38 of Set 7 | shipunovo
# Processing Record 39 of Set 7 | rundu
# Processing Record 40 of Set 7 | morro bay
# Processing Record 41 of Set 7 | iracoubo
# Processing Record 42 of Set 7 | boshan
# Processing Record 43 of Set 7 | vanimo
# Processing Record 44 of Set 7 | saint-pierre
# Processing Record 45 of Set 7 | yangambi
# Processing Record 46 of Set 7 | orzhytsya
# Processing Record 47 of Set 7 | cidreira
# Processing Record 48 of Set 7 | ambon
# Processing Record 49 of Set 7 | casma
# Processing Record 50 of Set 7 | lerwick
# Processing Record 1 of Set 8 | severomuysk
# Processing Record 2 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 8 | jacksonville beach
# Processing Record 4 of Set 8 | vavuniya
# Processing Record 5 of Set 8 | yialos
# City not found. Skipping...
# Processing Record 6 of Set 8 | crotone
# Processing Record 7 of Set 8 | port lincoln
# Processing Record 8 of Set 8 | itarema
# Processing Record 9 of Set 8 | pangnirtung
# Processing Record 10 of Set 8 | gallup
# Processing Record 11 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 8 | hambantota
# Processing Record 13 of Set 8 | urumqi
# Processing Record 14 of Set 8 | esterhazy
# Processing Record 15 of Set 8 | narsaq
# Processing Record 16 of Set 8 | kattivakkam
# Processing Record 17 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 18 of Set 8 | ibra
# Processing Record 19 of Set 8 | igarka
# Processing Record 20 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 8 | sillod
# Processing Record 22 of Set 8 | nago
# Processing Record 23 of Set 8 | linjiang
# Processing Record 24 of Set 8 | santa rosa
# Processing Record 25 of Set 8 | kashi
# Processing Record 26 of Set 8 | beloha
# Processing Record 27 of Set 8 | minot
# Processing Record 28 of Set 8 | lincoln
# Processing Record 29 of Set 8 | airai
# Processing Record 30 of Set 8 | sitangkai
# Processing Record 31 of Set 8 | izazi
# Processing Record 32 of Set 8 | quatre cocos
# Processing Record 33 of Set 8 | samarai
# Processing Record 34 of Set 8 | bowen
# Processing Record 35 of Set 8 | manta
# Processing Record 36 of Set 8 | charters towers
# Processing Record 37 of Set 8 | kaitangata
# Processing Record 38 of Set 8 | morgan city
# Processing Record 39 of Set 8 | gizo
# Processing Record 40 of Set 8 | faya
# Processing Record 41 of Set 8 | norman wells
# Processing Record 42 of Set 8 | novoyegoryevskoye
# City not found. Skipping...
# Processing Record 43 of Set 8 | sitka
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 46 of Set 8 | kralendijk
# Processing Record 47 of Set 8 | geraldton
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | zhigansk
# Processing Record 50 of Set 8 | iberia
# Processing Record 1 of Set 9 | meadow lake
# Processing Record 2 of Set 9 | altamont
# Processing Record 3 of Set 9 | namibe
# Processing Record 4 of Set 9 | moron
# Processing Record 5 of Set 9 | constitucion
# Processing Record 6 of Set 9 | jimma
# Processing Record 7 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 9 | buraydah
# Processing Record 10 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 9 | holme
# Processing Record 12 of Set 9 | chunskiy
# Processing Record 13 of Set 9 | puerto del rosario
# Processing Record 14 of Set 9 | nouadhibou
# Processing Record 15 of Set 9 | llanelli
# Processing Record 16 of Set 9 | udarnyy
# Processing Record 17 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 9 | pisco
# Processing Record 19 of Set 9 | mezen
# Processing Record 20 of Set 9 | belmonte
# Processing Record 21 of Set 9 | vitim
# Processing Record 22 of Set 9 | vic
# Processing Record 23 of Set 9 | bara
# Processing Record 24 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 25 of Set 9 | laguna
# Processing Record 26 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | negombo
# Processing Record 28 of Set 9 | boyuibe
# Processing Record 29 of Set 9 | shenjiamen
# Processing Record 30 of Set 9 | dorado
# Processing Record 31 of Set 9 | voyvozh
# Processing Record 32 of Set 9 | tubuala
# Processing Record 33 of Set 9 | ixtapa
# Processing Record 34 of Set 9 | san rafael
# Processing Record 35 of Set 9 | korla
# Processing Record 36 of Set 9 | at-bashi
# Processing Record 37 of Set 9 | verkhnevilyuysk
# Processing Record 38 of Set 9 | crossville
# Processing Record 39 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | robe
# Processing Record 41 of Set 9 | ajaccio
# Processing Record 42 of Set 9 | zopilotepe
# Processing Record 43 of Set 9 | ust-nera
# Processing Record 44 of Set 9 | carberry
# Processing Record 45 of Set 9 | dubbo
# Processing Record 46 of Set 9 | setermoen
# Processing Record 47 of Set 9 | calmar
# Processing Record 48 of Set 9 | tawang
# Processing Record 49 of Set 9 | praia
# Processing Record 50 of Set 9 | gazli
# Processing Record 1 of Set 10 | tongliao
# Processing Record 2 of Set 10 | yeppoon
# Processing Record 3 of Set 10 | abu zabad
# Processing Record 4 of Set 10 | beaverlodge
# Processing Record 5 of Set 10 | victoria
# Processing Record 6 of Set 10 | lagoa
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | ambulu
# Processing Record 9 of Set 10 | puerto madryn
# Processing Record 10 of Set 10 | fukue
# Processing Record 11 of Set 10 | bathsheba
# Processing Record 12 of Set 10 | te anau
# Processing Record 13 of Set 10 | khasan
# Processing Record 14 of Set 10 | esso
# Processing Record 15 of Set 10 | sistranda
# Processing Record 16 of Set 10 | xiashi
# Processing Record 17 of Set 10 | dawei
# Processing Record 18 of Set 10 | chifeng
# Processing Record 19 of Set 10 | libourne
# Processing Record 20 of Set 10 | bridgetown
# Processing Record 21 of Set 10 | kuytun
# Processing Record 22 of Set 10 | flinders
# Processing Record 23 of Set 10 | dillingen
# Processing Record 24 of Set 10 | asyut
# Processing Record 25 of Set 10 | koumac
# Processing Record 26 of Set 10 | opelousas
# Processing Record 27 of Set 10 | nizwa
# Processing Record 28 of Set 10 | yaan
# Processing Record 29 of Set 10 | labrea
# Processing Record 30 of Set 10 | samatau
# City not found. Skipping...
# Processing Record 31 of Set 10 | vallenar
# Processing Record 32 of Set 10 | villa rica
# Processing Record 33 of Set 10 | valle de allende
# Processing Record 34 of Set 10 | ponta delgada
# Processing Record 35 of Set 10 | tommot
# Processing Record 36 of Set 10 | ulladulla
# Processing Record 37 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 10 | teknaf
# Processing Record 39 of Set 10 | takaka
# Processing Record 40 of Set 10 | wahpeton
# Processing Record 41 of Set 10 | goderich
# Processing Record 42 of Set 10 | novikovo
# Processing Record 43 of Set 10 | kungurtug
# Processing Record 44 of Set 10 | wanning
# Processing Record 45 of Set 10 | port shepstone
# Processing Record 46 of Set 10 | marzuq
# Processing Record 47 of Set 10 | anloga
# Processing Record 48 of Set 10 | horsham
# Processing Record 49 of Set 10 | ocean city
# Processing Record 50 of Set 10 | wajima
# Processing Record 1 of Set 11 | baykit
# Processing Record 2 of Set 11 | bud
# Processing Record 3 of Set 11 | south river
# Processing Record 4 of Set 11 | araouane
# Processing Record 5 of Set 11 | lima
# Processing Record 6 of Set 11 | bandarbeyla
# Processing Record 7 of Set 11 | pakhtakoron
# Processing Record 8 of Set 11 | chingirlau
# Processing Record 9 of Set 11 | asuncion mita
# Processing Record 10 of Set 11 | carhuaz
# Processing Record 11 of Set 11 | rocha
# Processing Record 12 of Set 11 | la palma
# Processing Record 13 of Set 11 | eldoret
# Processing Record 14 of Set 11 | kawana waters
# City not found. Skipping...
# Processing Record 15 of Set 11 | bonthe
# Processing Record 16 of Set 11 | coihaique
# Processing Record 17 of Set 11 | mayumba
# Processing Record 18 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 19 of Set 11 | kholtoson
# Processing Record 20 of Set 11 | oyama
# Processing Record 21 of Set 11 | cap malheureux
# Processing Record 22 of Set 11 | liverpool
# Processing Record 23 of Set 11 | lyubokhna
# Processing Record 24 of Set 11 | aklavik
# Processing Record 25 of Set 11 | belaya gora
# Processing Record 26 of Set 11 | leh
# Processing Record 27 of Set 11 | ankpa
# Processing Record 28 of Set 11 | carnduff
# Processing Record 29 of Set 11 | bundaberg
# Processing Record 30 of Set 11 | werda
# Processing Record 31 of Set 11 | seymchan
# Processing Record 32 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 33 of Set 11 | gavrilovka vtoraya
# Processing Record 34 of Set 11 | mazamet
# Processing Record 35 of Set 11 | nishihara
# Processing Record 36 of Set 11 | fortuna
# Processing Record 37 of Set 11 | gamba
# Processing Record 38 of Set 11 | novaya igirma
# Processing Record 39 of Set 11 | vila franca do campo
# Processing Record 40 of Set 11 | vezirkopru
# Processing Record 41 of Set 11 | beinamar
# Processing Record 42 of Set 11 | san cristobal
# Processing Record 43 of Set 11 | yulara
# Processing Record 44 of Set 11 | marsh harbour
# Processing Record 45 of Set 11 | la rochelle
# Processing Record 46 of Set 11 | kuloy
# Processing Record 47 of Set 11 | kupang
# Processing Record 48 of Set 11 | manitouwadge
# Processing Record 49 of Set 11 | poum
# Processing Record 50 of Set 11 | turayf
# Processing Record 1 of Set 12 | benghazi
# Processing Record 2 of Set 12 | kambove
# Processing Record 3 of Set 12 | andros town
# Processing Record 4 of Set 12 | canutama
# Processing Record 5 of Set 12 | kununurra
# Processing Record 6 of Set 12 | kousseri
# Processing Record 7 of Set 12 | pinto
# Processing Record 8 of Set 12 | riyadh
# Processing Record 9 of Set 12 | sakaiminato
# Processing Record 10 of Set 12 | mabaruma
# Processing Record 11 of Set 12 | miles city
# Processing Record 12 of Set 12 | neiafu
# Processing Record 13 of Set 12 | rengo
# Processing Record 14 of Set 12 | puerto maldonado
# Processing Record 15 of Set 12 | mahibadhoo
# Processing Record 16 of Set 12 | gijon
# Processing Record 17 of Set 12 | komsomolets
# Processing Record 18 of Set 12 | linfen
# Processing Record 19 of Set 12 | vilhena
# Processing Record 20 of Set 12 | chany
# Processing Record 21 of Set 12 | purpe
# Processing Record 22 of Set 12 | san patricio
# Processing Record 23 of Set 12 | ust-tsilma
# Processing Record 24 of Set 12 | dolores
# Processing Record 25 of Set 12 | comodoro rivadavia
# Processing Record 26 of Set 12 | kaduqli
# Processing Record 27 of Set 12 | vrangel
# Processing Record 28 of Set 12 | ndele
# Processing Record 29 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 30 of Set 12 | grand gaube
# Processing Record 31 of Set 12 | waingapu
# Processing Record 32 of Set 12 | bage
# Processing Record 33 of Set 12 | datong
# Processing Record 34 of Set 12 | bakchar
# Processing Record 35 of Set 12 | sola
# Processing Record 36 of Set 12 | maceio
# Processing Record 37 of Set 12 | tonj
# Processing Record 38 of Set 12 | maetaguse
# City not found. Skipping...
# Processing Record 39 of Set 12 | sherbakul
# Processing Record 40 of Set 12 | platteville
# Processing Record 41 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 12 | kailua
# Processing Record 43 of Set 12 | kudahuvadhoo
# Processing Record 44 of Set 12 | husavik
# Processing Record 45 of Set 12 | laiagam
# City not found. Skipping...
# Processing Record 46 of Set 12 | bridgewater
# Processing Record 47 of Set 12 | livingston
# Processing Record 48 of Set 12 | wasilla
# Processing Record 49 of Set 12 | cockburn town
# Processing Record 50 of Set 12 | benjamin aceval
# Processing Record 1 of Set 13 | lompoc
# Processing Record 2 of Set 13 | gunjur
# Processing Record 3 of Set 13 | cabedelo
# Processing Record 4 of Set 13 | hofn
# Processing Record 5 of Set 13 | kutahya
# Processing Record 6 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 13 | yanam
# Processing Record 8 of Set 13 | godec
# City not found. Skipping...
# Processing Record 9 of Set 13 | taoudenni
# Processing Record 10 of Set 13 | silver city
# Processing Record 11 of Set 13 | evanston
# Processing Record 12 of Set 13 | tonstad
# Processing Record 13 of Set 13 | vaitape
# Processing Record 14 of Set 13 | jumla
# Processing Record 15 of Set 13 | guatire
# Processing Record 16 of Set 13 | kavaratti
# Processing Record 17 of Set 13 | krasnoselkup
# Processing Record 18 of Set 13 | lata
# Processing Record 19 of Set 13 | kangaba
# Processing Record 20 of Set 13 | hervey bay
# Processing Record 21 of Set 13 | barcs
# Processing Record 22 of Set 13 | hohhot
# Processing Record 23 of Set 13 | isla mujeres
# Processing Record 24 of Set 13 | san quintin
# Processing Record 25 of Set 13 | raudeberg
# Processing Record 26 of Set 13 | namatanai
# Processing Record 27 of Set 13 | sobolevo
# Processing Record 28 of Set 13 | opuwo
# Processing Record 29 of Set 13 | alta floresta
# Processing Record 30 of Set 13 | bubaque
# Processing Record 31 of Set 13 | bolshaya murta
# City not found. Skipping...
# Processing Record 32 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 13 | hatta
# Processing Record 34 of Set 13 | huarmey
# Processing Record 35 of Set 13 | nha trang
# Processing Record 36 of Set 13 | cordoba
# Processing Record 37 of Set 13 | tuy hoa
# Processing Record 38 of Set 13 | jashpurnagar
# Processing Record 39 of Set 13 | kedougou
# Processing Record 40 of Set 13 | suntar
# Processing Record 41 of Set 13 | chitipa
# Processing Record 42 of Set 13 | samdari
# Processing Record 43 of Set 13 | dunedin
# Processing Record 44 of Set 13 | san juan
# Processing Record 45 of Set 13 | abu samrah
# Processing Record 46 of Set 13 | zaykovo
# Processing Record 47 of Set 13 | lao cai
# Processing Record 48 of Set 13 | buckeye
# Processing Record 49 of Set 13 | jabinyanah
# Processing Record 50 of Set 13 | bar harbor
# Processing Record 1 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 2 of Set 14 | yerbogachen
# Processing Record 3 of Set 14 | kamalpur
# Processing Record 4 of Set 14 | presidencia roque saenz pena
# Processing Record 5 of Set 14 | nagato
# Processing Record 6 of Set 14 | the pas
# Processing Record 7 of Set 14 | nyrob
# Processing Record 8 of Set 14 | dauriya
# Processing Record 9 of Set 14 | forecariah
# Processing Record 10 of Set 14 | rio grande
# Processing Record 11 of Set 14 | serebryansk
# Processing Record 12 of Set 14 | orange cove
# Processing Record 13 of Set 14 | brentwood
# Processing Record 14 of Set 14 | asmara
# Processing Record 15 of Set 14 | southwick
# Processing Record 16 of Set 14 | alotau
# City not found. Skipping...
# Processing Record 17 of Set 14 | sangolqui
# Processing Record 18 of Set 14 | port macquarie
# Processing Record 19 of Set 14 | santa cruz
# Processing Record 20 of Set 14 | promyshlennyy
# Processing Record 21 of Set 14 | arinos
# Processing Record 22 of Set 14 | ban chang
# Processing Record 23 of Set 14 | fier
# Processing Record 24 of Set 14 | karatau
# Processing Record 25 of Set 14 | sayyan
# Processing Record 26 of Set 14 | balkanabat
# Processing Record 27 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 28 of Set 14 | hoi an
# Processing Record 29 of Set 14 | tefe
# Processing Record 30 of Set 14 | sao felix do xingu
# Processing Record 31 of Set 14 | vredendal
# Processing Record 32 of Set 14 | gigmoto
# Processing Record 33 of Set 14 | genhe
# Processing Record 34 of Set 14 | srednekolymsk
# Processing Record 35 of Set 14 | pleasant point
# Processing Record 36 of Set 14 | banda aceh
# Processing Record 37 of Set 14 | general pico
# Processing Record 38 of Set 14 | oeiras do para
# Processing Record 39 of Set 14 | conde
# Processing Record 40 of Set 14 | pyapon
# Processing Record 41 of Set 14 | sulphur
# Processing Record 42 of Set 14 | port hedland
# Processing Record 43 of Set 14 | mokshan
# Processing Record 44 of Set 14 | glendive
# Processing Record 45 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 14 | redhakhol
# City not found. Skipping...
# Processing Record 47 of Set 14 | maniwaki
# Processing Record 48 of Set 14 | elko
# Processing Record 49 of Set 14 | turukhansk
# Processing Record 50 of Set 14 | messina
# Processing Record 1 of Set 15 | manicore
# Processing Record 2 of Set 15 | bang saphan
# Processing Record 3 of Set 15 | pitimbu
# Processing Record 4 of Set 15 | rize
# Processing Record 5 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 15 | baripada
# Processing Record 7 of Set 15 | patuli
# Processing Record 8 of Set 15 | ximei
# Processing Record 9 of Set 15 | mecca
# Processing Record 10 of Set 15 | moree
# Processing Record 11 of Set 15 | zhanaozen
# Processing Record 12 of Set 15 | zinder
# Processing Record 13 of Set 15 | joshimath
# Processing Record 14 of Set 15 | oxford
# Processing Record 15 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 15 | los llanos de aridane
# Processing Record 17 of Set 15 | manuk mangkaw
# Processing Record 18 of Set 15 | carutapera
# Processing Record 19 of Set 15 | tukrah
# Processing Record 20 of Set 15 | gidam
# Processing Record 21 of Set 15 | antequera
# Processing Record 22 of Set 15 | qui nhon
# Processing Record 23 of Set 15 | sampit
# Processing Record 24 of Set 15 | havoysund
# Processing Record 25 of Set 15 | kasongo-lunda
# Processing Record 26 of Set 15 | kyra
# Processing Record 27 of Set 15 | hualmay
# Processing Record 28 of Set 15 | puerto escondido
# Processing Record 29 of Set 15 | mehamn
# Processing Record 30 of Set 15 | coxim
# Processing Record 31 of Set 15 | beringovskiy
# Processing Record 32 of Set 15 | phalaborwa
# Processing Record 33 of Set 15 | gat
# Processing Record 34 of Set 15 | wanaka
# Processing Record 35 of Set 15 | berdigestyakh
# Processing Record 36 of Set 15 | brewster
# Processing Record 37 of Set 15 | coquimbo
# Processing Record 38 of Set 15 | ugoofaaru
# Processing Record 39 of Set 15 | yabrud
# Processing Record 40 of Set 15 | haines junction
# Processing Record 41 of Set 15 | misratah
# Processing Record 42 of Set 15 | saint austell
# Processing Record 43 of Set 15 | vao
# Processing Record 44 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 45 of Set 15 | marantao
# Processing Record 46 of Set 15 | rosita
# Processing Record 47 of Set 15 | raga
# Processing Record 48 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 49 of Set 15 | likhoy
# Processing Record 50 of Set 15 | pundaguitan
# Processing Record 1 of Set 16 | nyurba
# Processing Record 2 of Set 16 | gwadar
# Processing Record 3 of Set 16 | lebanon
# Processing Record 4 of Set 16 | rabo de peixe
# Processing Record 5 of Set 16 | urengoy
# Processing Record 6 of Set 16 | balsas
# Processing Record 7 of Set 16 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 16 | athabasca
# Processing Record 9 of Set 16 | kawalu
# Processing Record 10 of Set 16 | caluquembe
# Processing Record 11 of Set 16 | jiayuguan
# Processing Record 12 of Set 16 | souillac
# Processing Record 13 of Set 16 | yumen
# Processing Record 14 of Set 16 | richards bay
# Processing Record 15 of Set 16 | iranshahr
# Processing Record 16 of Set 16 | kidal
# Processing Record 17 of Set 16 | bridlington
# Processing Record 18 of Set 16 | lingao
# Processing Record 19 of Set 16 | arlit
# Processing Record 20 of Set 16 | birao
# Processing Record 21 of Set 16 | sergeyevka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Ushuaia      AR -54.8000  -68.3000     40.62        75           0
# 1       Smithers      CA  54.7804 -127.1743     37.72       100           0
# 2       Saldanha      ZA -33.0117   17.9442     56.98        72           0
# 3        Rikitea      PF -23.1203 -134.9692     73.08        75           0
# 4       Cherskiy      RU  68.7500  161.3000     40.91        43          92
# 5         Hobart      AU -42.8794  147.3294     60.66        65           0
# 6     Oranjemund      NA -28.5500   16.4333     56.80        59           0
# 7  Alice Springs      AU -23.7000  133.8833     90.95        14         100
# 8        Aguimes      ES  27.9054  -15.4461     68.63        83          20
# 9      Busselton      AU -33.6500  115.3333     63.21        67           5
#
#    Wind Speed Current Description
# 0        3.44           clear sky
# 1        0.00                mist
# 2        5.23           clear sky
# 3       13.91           clear sky
# 4       12.71     overcast clouds
# 5        5.75           clear sky
# 6        8.14           clear sky
# 7       19.57     overcast clouds
# 8        6.91          few clouds
# 9       17.34           clear sky

# %%
# Convert DF to CSV
csv_weather_file = "WeatherPy_Database.csv"

# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
